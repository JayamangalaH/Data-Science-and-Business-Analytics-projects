# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt   
import seaborn as sns
# %matplotlib inline

# %%
import nltk
nltk.download('inaugural')
from nltk.corpus import inaugural
inaugural.fileids()
inaugural.raw('1941-Roosevelt.txt')
inaugural.raw('1961-Kennedy.txt')
inaugural.raw('1973-Nixon.txt')
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\jayam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\inaugural.zip.
# ...

# %%
roosecount=inaugural.words('1941-Roosevelt.txt')
print("Number of words in Roosevlet_txt -",len(roosecount))
kennedycount=inaugural.words('1961-Kennedy.txt')
print("Number of words in Kennedy_txt -",len(kennedycount))
nixoncount=inaugural.words('1973-Nixon.txt')
print("Number of words in Nixon_txt -",len(nixoncount))
# Out:
# Number of words in Roosevlet_txt - 1536
# Number of words in Kennedy_txt - 1546
# Number of words in Nixon_txt - 2028

# %%
roosesents=inaugural.sents('1941-Roosevelt.txt')
print("Number of sentences in Roosevlet_txt - ",len(roosesents))
kennedysents=inaugural.sents('1961-Kennedy.txt')
print("Number of sentences in Kennedy_txt -",len(kennedysents))
nixonsents=inaugural.sents('1973-Nixon.txt')
print("Number of sentences in Nixon_txt -",len(nixonsents))
# Out:
# Number of sentences in Roosevlet_txt -  68
# Number of sentences in Kennedy_txt - 52
# Number of sentences in Nixon_txt - 69

# %%
rcc=inaugural.raw('1941-Roosevelt.txt')
print("char count including spaces, symbols, punctuation in Roosevlet_txt -",len(rcc))
kcc=inaugural.raw('1961-Kennedy.txt')
print("char count including spaces, symbols, punctuation in Kennedy_txt -",len(kcc))
ncc=inaugural.raw('1973-Nixon.txt')
print("char count including spaces, symbols, punctuation in Nixon_txt -",len(ncc))
# Out:
# char count including spaces, symbols, punctuation in Roosevlet_txt - 7571
# char count including spaces, symbols, punctuation in Kennedy_txt - 7618
# char count including spaces, symbols, punctuation in Nixon_txt - 9991

# %%
from nltk.stem import PorterStemmer
import re

rv=inaugural.raw('1941-Roosevelt.txt')
#rv1=re.split(r'\W+', rv)
all_stopwords = stopwords.words('english')
#words = nltk.word_tokenize(rv)
words_r = re.split(r'\W+', rv)
# Remove single-character tokens (mostly punctuation)
words_r = [word for word in words_r if len(word) > 1]

# Remove numbers
words_r = [word for word in words_r if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words_r = [word.lower() for word in words_r]

# Remove stopwords
words_r = [word for word in words_r if word not in all_stopwords]
roose_df = pd.DataFrame(words_r,columns=['Roosevelt words list'])
print("List of words after removing stopwords in the Roosevelt_txt are\n\n", roose_df,"\n\n")

# Calculate frequency distribution
fdist = nltk.FreqDist(words_r)
print("Top three words occuring most number of times in the Roosevelt_txt are\n\n")
print("word;count frequency")
print("....................")
# Output top 3 words

for word, frequency in fdist.most_common(3):
    print(u'{};{}'.format(word, frequency))
# Out:
# List of words after removing stopwords in the Roosevelt_txt are
#
#      Roosevelt words list
# 0               national
# 1                    day
# 2           inauguration
# 3                  since
# 4                 people
# ..                   ...
# 622                   go
# 623              forward
# 624              service
# 625              country
# 626                  god
#
# [627 rows x 1 columns]
#
#
# Top three words occuring most number of times in the Roosevelt_txt are
#
#
# word;count frequency
# ....................
# nation;12
# know;10
# spirit;9

# %%
kv=inaugural.raw('1961-Kennedy.txt')
all_stopwords = stopwords.words('english')
#words = nltk.word_tokenize(rv)
words_k = re.split(r'\W+', kv)
# Remove single-character tokens (mostly punctuation)
words_k = [word for word in words_k if len(word) > 1]

# Remove numbers
words_k = [word for word in words_k if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words_k = [word.lower() for word in words_k]

# Remove stopwords
words_k = [word for word in words_k if word not in all_stopwords]
ken_df = pd.DataFrame(words_k,columns=['Kennedy words list'])
print("List of words after removing stopwords in Kennedy_txt are\n\n", ken_df,"\n\n")

# Calculate frequency distribution
fdist = nltk.FreqDist(words_k)
print("Top three words occuring most number of times in the Kennedy_txt are\n\n")
print("word;count frequency")
print("....................")
# Output top 3 words

for word, frequency in fdist.most_common(3):
    print(u'{};{}'.format(word, frequency))
# Out:
# List of words after removing stopwords in Kennedy_txt are
#
#      Kennedy words list
# 0                 vice
# 1            president
# 2              johnson
# 3                   mr
# 4              speaker
# ..                 ...
# 686              earth
# 687                god
# 688               work
# 689               must
# 690              truly
#
# [691 rows x 1 columns]
#
#
# Top three words occuring most number of times in the Kennedy_txt are
#
#
# word;count frequency
# ....................
# let;16
# us;12
# world;8

# %%
nv = inaugural.raw('1973-Nixon.txt')
all_stopwords = stopwords.words('english')
#words = nltk.word_tokenize(rv)
words_n = re.split(r'\W+', nv)
# Remove single-character tokens (mostly punctuation)
words_n = [word for word in words_n if len(word) > 1]

# Remove numbers
words_n = [word for word in words_n if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words_n = [word.lower() for word in words_n]

# Remove stopwords
words_n = [word for word in words_n if word not in all_stopwords]

nix_df = pd.DataFrame(words_n,columns=['Nixon words list'])
print("List of words after removing stopwords in Nixon_txt are\n\n", nix_df,"\n\n")

# Calculate frequency distribution
fdist = nltk.FreqDist(words_n)
print("Top three words occuring most number of times in the Nixon_txt are\n\n")
print("word;count frequency")
print("....................")
# Output top 3 words

for word, frequency in fdist.most_common(3):
    print(u'{};{}'.format(word, frequency))
# Out:
# List of words after removing stopwords in Nixon_txt are
#
#      Nixon words list
# 0                 mr
# 1               vice
# 2          president
# 3                 mr
# 4            speaker
# ..               ...
# 829               us
# 830         striving
# 831           always
# 832            serve
# 833          purpose
#
# [834 rows x 1 columns]
#
#
# Top three words occuring most number of times in the Nixon_txt are
#
#
# word;count frequency
# ....................
# us;26
# let;22
# america;21

# %%
roose_df=pd.DataFrame(words_r,columns=['Roosevelt'])
ken_df=pd.DataFrame(words_k,columns=['Kennedy'])
nix_df=pd.DataFrame(words_n,columns=['Nixon'])

# %%
#word cloud
from wordcloud import WordCloud,STOPWORDS
words = ' '.join(roose_df['Roosevelt'])
cleaned_word_r = " ".join([word for word in words.split()])

wordcloud_r = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word_r)
plt.figure(1,figsize=(20, 12))
plt.imshow(wordcloud_r)
plt.axis('off')
plt.show()

# %%
#word cloud
words = ' '.join(ken_df['Kennedy'])
cleaned_word_k = " ".join([word for word in words.split()])

wordcloud_k = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word_k)
plt.figure(1,figsize=(20, 12))
plt.imshow(wordcloud_k)
plt.axis('off')
plt.show()

# %%
#word cloud
words = ' '.join(nix_df['Nixon'])
cleaned_word_n = " ".join([word for word in words.split()])

wordcloud_n = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word_n)
plt.figure(1,figsize=(20, 12))
plt.imshow(wordcloud_n)
plt.axis('off')
plt.show()
